# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("fundamentals.csv")
df.head()
# Out:
#    Unnamed: 0 Ticker Symbol Period Ending  Accounts Payable  \
# 0           0           AAL    2012-12-31      3.068000e+09
# 1           1           AAL    2013-12-31      4.975000e+09
# 2           2           AAL    2014-12-31      4.668000e+09
# 3           3           AAL    2015-12-31      5.102000e+09
# 4           4           AAP    2012-12-29      2.409453e+09
#
#    Accounts Receivable  Add'l income/expense items  After Tax ROE  \
# 0         -222000000.0               -1.961000e+09           23.0
# 1          -93000000.0               -2.723000e+09           67.0
# 2         -160000000.0               -1.500000e+08          143.0
# 3          352000000.0               -7.080000e+08          135.0
# 4          -89482000.0                6.000000e+05           32.0
#
#    Capital Expenditures  Capital Surplus  Cash Ratio  ...  \
# 0         -1.888000e+09     4.695000e+09        53.0  ...
# 1         -3.114000e+09     1.059200e+10        75.0  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1781 entries, 0 to 1780
# Data columns (total 79 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Unnamed: 0                                           1781 non-null   int64
#  1   Ticker Symbol                                        1781 non-null   object
#  2   Period Ending                                        1781 non-null   object
#  3   Accounts Payable                                     1781 non-null   float64
#  4   Accounts Receivable                                  1781 non-null   float64
#  5   Add'l income/expense items                           1781 non-null   float64
#  6   After Tax ROE                                        1781 non-null   float64
#  7   Capital Expenditures                                 1781 non-null   float64
# ...

# %%
df.describe()
# Out:
#         Unnamed: 0  Accounts Payable  Accounts Receivable  \
# count  1781.000000      1.781000e+03         1.781000e+03
# mean    890.000000      4.673418e+09        -6.353484e+07
# std     514.274732      1.406047e+10         7.562794e+08
# min       0.000000      0.000000e+00        -6.452000e+09
# 25%     445.000000      5.160000e+08        -1.040000e+08
# 50%     890.000000      1.334000e+09        -1.830000e+07
# 75%    1335.000000      3.246000e+09         7.816000e+06
# max    1780.000000      2.069390e+11         2.266400e+10
#
#        Add'l income/expense items  After Tax ROE  Capital Expenditures  \
# count                1.781000e+03    1781.000000          1.781000e+03
# mean                 6.908940e+07      43.601348         -1.251925e+09
# std                  6.848143e+08     233.924028          2.979963e+09
# min                 -6.768000e+09       0.000000         -3.798500e+10
# 25%                 -2.638000e+06      10.000000         -1.151200e+09
# ...

# %% [markdown]
# ### Mean, Medium, Mode and Standard deviation:

# %%
df.mean()
# Out:
# C:\Users\User15\AppData\Local\Temp\ipykernel_16792\3698961737.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# Unnamed: 0                      8.900000e+02
# Accounts Payable                4.673418e+09
# Accounts Receivable            -6.353484e+07
# Add'l income/expense items      6.908940e+07
# After Tax ROE                   4.360135e+01
#                                     ...
# Total Revenue                   2.029154e+10
# Treasury Stock                 -3.951522e+09
# For Year                        2.013305e+03
# Earnings Per Share              3.353707e+00
# Estimated Shares Outstanding    6.024244e+08
# Length: 77, dtype: float64

# %%
df.head()
# Out:
#    Unnamed: 0 Ticker Symbol Period Ending  Accounts Payable  \
# 0           0           AAL    2012-12-31      3.068000e+09
# 1           1           AAL    2013-12-31      4.975000e+09
# 2           2           AAL    2014-12-31      4.668000e+09
# 3           3           AAL    2015-12-31      5.102000e+09
# 4           4           AAP    2012-12-29      2.409453e+09
#
#    Accounts Receivable  Add'l income/expense items  After Tax ROE  \
# 0         -222000000.0               -1.961000e+09           23.0
# 1          -93000000.0               -2.723000e+09           67.0
# 2         -160000000.0               -1.500000e+08          143.0
# 3          352000000.0               -7.080000e+08          135.0
# 4          -89482000.0                6.000000e+05           32.0
#
#    Capital Expenditures  Capital Surplus  Cash Ratio  ...  \
# 0         -1.888000e+09     4.695000e+09        53.0  ...
# 1         -3.114000e+09     1.059200e+10        75.0  ...
# ...

# %% [markdown]
# ### Correlation:

# %%
corr_matrix = df.corr()
sns.heatmap(corr_matrix)
# Out:
# C:\Users\User15\AppData\Local\Temp\ipykernel_16792\2646304368.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df.corr()
# <Axes: >

# %% [markdown]
# ### Check Null Values:

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                        0
# Ticker Symbol                     0
# Period Ending                     0
# Accounts Payable                  0
# Accounts Receivable               0
#                                ...
# Total Revenue                     0
# Treasury Stock                    0
# For Year                        173
# Earnings Per Share              219
# Estimated Shares Outstanding    219
# Length: 79, dtype: int64

# %% [markdown]
# ### Drop Null Values:

# %%
df.columns[df.isnull().mean()>0.75]
# Out:
# Index([], dtype='object')

# %% [markdown]
# ### There is no Null values >75%

# %%
df.isnull().sum()/len(df)*100
# Out:
# Unnamed: 0                       0.000000
# Ticker Symbol                    0.000000
# Period Ending                    0.000000
# Accounts Payable                 0.000000
# Accounts Receivable              0.000000
#                                   ...
# Total Revenue                    0.000000
# Treasury Stock                   0.000000
# For Year                         9.713644
# Earnings Per Share              12.296463
# Estimated Shares Outstanding    12.296463
# Length: 79, dtype: float64

# %%
df2 = df[df.columns[df.isnull().any()]]

# %%
df2
# Out:
#       Cash Ratio  Current Ratio  Quick Ratio  For Year  Earnings Per Share  \
# 0           53.0           78.0         72.0    2012.0               -5.60
# 1           75.0          104.0         96.0    2013.0              -11.25
# 2           60.0           88.0         80.0    2014.0                4.02
# 3           51.0           73.0         67.0    2015.0               11.39
# 4           23.0          124.0         34.0    2012.0                5.29
# ...          ...            ...          ...       ...                 ...
# 1776         NaN            NaN          NaN    2015.0                1.20
# 1777        43.0          237.0        146.0    2013.0                1.01
# 1778        81.0          319.0        200.0    2014.0                1.16
# 1779        65.0          215.0        133.0    2015.0                0.68
# 1780        65.0          303.0        169.0       NaN                 NaN
#
#       Estimated Shares Outstanding
# ...

# %% [markdown]
# ### Get data type of the null values column:

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1781 entries, 0 to 1780
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Cash Ratio                    1482 non-null   float64
#  1   Current Ratio                 1482 non-null   float64
#  2   Quick Ratio                   1482 non-null   float64
#  3   For Year                      1608 non-null   float64
#  4   Earnings Per Share            1562 non-null   float64
#  5   Estimated Shares Outstanding  1562 non-null   float64
# dtypes: float64(6)
# memory usage: 83.6 KB

# %% [markdown]
# ### Replace the Null Values as 0.00

# %%
df.fillna(0.00)
# Out:
#       Unnamed: 0 Ticker Symbol Period Ending  Accounts Payable  \
# 0              0           AAL    2012-12-31      3.068000e+09
# 1              1           AAL    2013-12-31      4.975000e+09
# 2              2           AAL    2014-12-31      4.668000e+09
# 3              3           AAL    2015-12-31      5.102000e+09
# 4              4           AAP    2012-12-29      2.409453e+09
# ...          ...           ...           ...               ...
# 1776        1776          ZION    2015-12-31      0.000000e+00
# 1777        1777           ZTS    2013-12-31      1.381000e+09
# 1778        1778           ZTS    2014-12-31      1.071000e+09
# 1779        1779           ZTS    2015-12-31      1.313000e+09
# 1780        1780           ZTS    2016-12-31      1.076000e+09
#
#       Accounts Receivable  Add'l income/expense items  After Tax ROE  \
# 0            -222000000.0               -1.961000e+09           23.0
# ...

# %%
a=df2.fillna(0.00)
a.head()
# Out:
#    Cash Ratio  Current Ratio  Quick Ratio  For Year  Earnings Per Share  \
# 0        53.0           78.0         72.0    2012.0               -5.60
# 1        75.0          104.0         96.0    2013.0              -11.25
# 2        60.0           88.0         80.0    2014.0                4.02
# 3        51.0           73.0         67.0    2015.0               11.39
# 4        23.0          124.0         34.0    2012.0                5.29
#
#    Estimated Shares Outstanding
# 0                  3.350000e+08
# 1                  1.630222e+08
# 2                  7.169154e+08
# 3                  6.681299e+08
# 4                  7.328355e+07

# %%
#a['Cash Ratio']=a['Cash Ratio'].replace(0.00,a['Cash Ratio'].mean())

# %%
a.describe()
# Out:
#         Cash Ratio  Current Ratio  Quick Ratio     For Year  \
# count  1781.000000    1781.000000  1781.000000  1781.000000
# mean     61.957327     155.415497   122.281864  1817.740034
# std      97.375518     136.095543   121.353422   596.695941
# min       0.000000       0.000000     0.000000     0.000000
# 25%       6.000000      78.000000    52.000000  2013.000000
# 50%      30.000000     132.000000   101.000000  2014.000000
# 75%      76.000000     204.000000   160.000000  2015.000000
# max    1041.000000    1197.000000  1197.000000  2016.000000
#
#        Earnings Per Share  Estimated Shares Outstanding
# count         1781.000000                  1.781000e+03
# mean             2.941319                  5.283475e+08
# std              4.533432                  1.088136e+09
# min            -61.200000                 -1.513945e+09
# 25%              1.000000                  1.155952e+08
# 50%              2.470000                  2.408173e+08
# ...

# %%
means = a.describe().loc['mean']

# %%
a=a.replace(0.00,np.nan)

# %%
a=a.fillna(means)

# %%
a
# Out:
#       Cash Ratio  Current Ratio  Quick Ratio     For Year  Earnings Per Share  \
# 0      53.000000      78.000000    72.000000  2012.000000           -5.600000
# 1      75.000000     104.000000    96.000000  2013.000000          -11.250000
# 2      60.000000      88.000000    80.000000  2014.000000            4.020000
# 3      51.000000      73.000000    67.000000  2015.000000           11.390000
# 4      23.000000     124.000000    34.000000  2012.000000            5.290000
# ...          ...            ...          ...          ...                 ...
# 1776   61.957327     155.415497   122.281864  2015.000000            1.200000
# 1777   43.000000     237.000000   146.000000  2013.000000            1.010000
# 1778   81.000000     319.000000   200.000000  2014.000000            1.160000
# 1779   65.000000     215.000000   133.000000  2015.000000            0.680000
# 1780   65.000000     303.000000   169.000000  1817.740034            2.941319
#
# ...

# %%
means
# Out:
# Cash Ratio                      6.195733e+01
# Current Ratio                   1.554155e+02
# Quick Ratio                     1.222819e+02
# For Year                        1.817740e+03
# Earnings Per Share              2.941319e+00
# Estimated Shares Outstanding    5.283475e+08
# Name: mean, dtype: float64

# %%
sns.distplot(a['Cash Ratio'])
# Out:
# C:\Users\User15\AppData\Local\Temp\ipykernel_16792\2449158298.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a['Cash Ratio'])
# <Axes: xlabel='Cash Ratio', ylabel='Density'>

# %%
sns.distplot(a['Current Ratio'])
# Out:
# C:\Users\User15\AppData\Local\Temp\ipykernel_16792\2329083269.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a['Current Ratio'])
# <Axes: xlabel='Current Ratio', ylabel='Density'>

# %%
sns.distplot(a['Quick Ratio'])
# Out:
# C:\Users\User15\AppData\Local\Temp\ipykernel_16792\1256052446.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a['Quick Ratio'])
# <Axes: xlabel='Quick Ratio', ylabel='Density'>

# %%
sns.distplot(a['For Year'])
sns.distplot(a['Earnings Per Share'])
sns.distplot(a['Estimated Shares Outstanding'])
# Out:
# C:\Users\User15\AppData\Local\Temp\ipykernel_16792\1988441174.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a['For Year'])
# C:\Users\User15\AppData\Local\Temp\ipykernel_16792\1988441174.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
# check the co-linearity of every column.

for column in correlation_matrix:
    collinear_columns = correlation_matrix[abs(correlation_matrix[column]) > 0.8].index.tolist()
    collinear_columns.remove(column)
    if collinear_columns:
        print(f"Column '{column}' is collinear with the following columns: {collinear_columns}")
    else:
        print(f"Column '{column}' is not collinear with any other column.")
# Out:
# Column 'Unnamed: 0' is not collinear with any other column.
# Column 'Accounts Payable' is collinear with the following columns: ['Cash and Cash Equivalents', 'Short-Term Debt / Current Portion of Long-Term Debt', 'Total Assets', 'Total Liabilities', 'Total Liabilities & Equity']
# Column 'Accounts Receivable' is not collinear with any other column.
# Column 'Add'l income/expense items' is not collinear with any other column.
# Column 'After Tax ROE' is collinear with the following columns: ['Pre-Tax ROE']
# Column 'Capital Expenditures' is collinear with the following columns: ['Deferred Liability Charges', 'Depreciation', 'Fixed Assets']
# Column 'Capital Surplus' is not collinear with any other column.
# Column 'Cash Ratio' is collinear with the following columns: ['Current Ratio', 'Quick Ratio']
# ...

# %%
import pandas as pd
from pandas_profiling import ProfileReport
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[30], line 2
#       1 import pandas as pd
# ----> 2 from pandas_profiling import ProfileReport
#
# ModuleNotFoundError: No module named 'pandas_profiling'
